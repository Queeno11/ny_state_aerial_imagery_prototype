# %%
from src.utils.paths import EXTERNAL_DATA_DIR, NY_IMAGERY_ROOT

# %%
import pandas as pd
import geopandas as gpd


building_heights = gpd.read_file(r"C:\Users\abbat\Downloads\buildings-with-height-coverage.geojson")
building_heights.loc[:, "quadkey"] = building_heights["quadkey"].str[:9]
building_links = pd.read_csv(r"C:\Users\abbat\Downloads\dataset-links.csv", dtype={"QuadKey":str})\
    .rename(columns={"QuadKey":"quadkey"})
us_building_links = building_links[building_links["Location"]=="UnitedStates"]

# %%
import gdal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import gdal
#
# ModuleNotFoundError: No module named 'gdal'

# %%
building_heights

# %%
us_building_links = building_heights.merge(us_building_links, on="quadkey", validate="m:1", how="inner")

# %%
us_building_links.Url[0]

# %%
building_heights

# %%
ny = gpd.read_file(r"C:\Users\abbat\Downloads\NewYork.geojson.zip")

# %%
ny.iloc[:1000].explore(
        tiles="https://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr="asd"
)

# %%
ny

# %% [markdown]
# # Visualizer

# %%
# Vizualizer

m = gpd.read_file(r"C:\Users\abbat\Downloads\part-00155-66ec874b-f074-4991-9da4-67716003c6cd.c000.csv\part-00155-66ec874b-f074-4991-9da4-67716003c6cd.c000.geojson").explore(
    tiles="https://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr="asd"
)
building_heights[building_heights.quadkey.str[:9] == "021323231"].explore(m=m, )
